# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas as pd
data = pd.read_csv('E:\python\Ecommerce - UK Retailer.csv',encoding = 'ISO-8859-1')
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
import seaborn as sns

# %%
#1. Perform Basic EDA

# %%
#a. Boxplot – All Numeric Variables 
plt.subplots(figsize=(8,6))
sns.boxplot(data.UnitPrice)

plt.xlabel('Unit Price')
plt.title('Boxplot for Unit Price')
plt.show()

plt.subplots(figsize=(8,6))
sns.boxplot(data.Quantity)

plt.xlabel('Quantity')
plt.title('Boxplot for quantity')
plt.show()

# %%
#b. Histogram – All Numeric Variables 

plt.subplot(3,1,1)
plt.title("unit price distribution")
plt.hist(data['UnitPrice'],color='red')
print()
print()

plt.subplot(3,1,2)
plt.title("Quantity distribution")
plt.hist(data['Quantity'],color='blue')
plt.tight_layout()

# %%
#c. Distribution Plot – All Numeric Variables 

import seaborn as sns
import matplotlib.pyplot as plt
plt.subplots(figsize=(6,3))
sns.distplot(data.UnitPrice[data.UnitPrice < 50], label='Unit Price').legend()

plt.xlabel('Unit Price')
plt.ylabel('Normalized Distribution')
plt.title('Unit Price Distribution')
plt.show()


plt.subplots(figsize=(6,3))
sns.distplot(data.Quantity[data.Quantity < 50], label='Unit Price').legend()

plt.xlabel('Quantity')
plt.ylabel('Normalized Distribution')
plt.title('Quantity Distribution')
plt.show()

# %%
#d. Aggregation for all numerical Columns

data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data['total_amount'] = data['Quantity'] * data['UnitPrice']
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  total_amount
# ...

# %%
data['InvoiceDate'] = pd.to_datetime(data.InvoiceDate, format='%m/%d/%Y %H:%M')
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_amount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom         15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom         22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  total_amount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom         15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom         22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom         20.34

# %%
#e. Unique Values across all columns 

column_values = data[["InvoiceNo", "StockCode" ,"Description" , "Quantity" , "InvoiceDate" ,"UnitPrice" , "CustomerID" , "Country" , "total_amount"]]. values. ravel()
unique_values = pd. unique(column_values)
print(unique_values)
# Out:
# ['536365' '85123A' 'WHITE HANGING HEART T-LIGHT HOLDER' ...
#  Timestamp('2011-12-09 12:49:00') '581587'
#  Timestamp('2011-12-09 12:50:00')]

# %%
#data.insert(loc=2, column='year', value=pd.DatetimeIndex(data['InvoiceDate']).map(lambda x:x.year))
data.head()
# Out:
#   InvoiceNo StockCode  year                          Description  Quantity  \
# 0    536365    85123A  2010   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053  2010                  WHITE METAL LANTERN         6
# 2    536365    84406B  2010       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  2010  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E  2010       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
#f. Duplicate values across all columns
duplicate = data[data.duplicated()] 
  
print("Duplicate Rows :")
duplicate
# Out:
# Duplicate Rows :
#        InvoiceNo StockCode  year_month                        Description  \
# 517       536409     21866      201012        UNION JACK FLAG LUGGAGE TAG
# 527       536409     22866      201012      HAND WARMER SCOTTY DOG DESIGN
# 537       536409     22900      201012    SET 2 TEA TOWELS I LOVE LONDON
# 539       536409     22111      201012       SCOTTIE DOG HOT WATER BOTTLE
# 555       536412     22327      201012  ROUND SNACK BOXES SET OF 4 SKULLS
# ...          ...       ...         ...                                ...
# 541675    581538     22068      201112        BLACK PIRATE TREASURE CHEST
# 541689    581538     23318      201112     BOX OF 6 MINI VINTAGE CRACKERS
# 541692    581538     22992      201112             REVOLVER WOODEN RULER
# 541699    581538     22694      201112                       WICKER STAR
# 541701    581538     23343      201112       JUMBO BAG VINTAGE CHRISTMAS
#
# ...

# %%
#g. Correlation – Heatmap - All Numeric Variables 
import seaborn as sns
sns.heatmap(data.corr())

# %%
#h. Regression Plot - All Numeric Variables 

sns.regplot(x="Quantity", y="UnitPrice", data=data);

# %%
#i. Bar Plot – Every Categorical Variable vs every Numerical Variable 


grouped_CO= data.groupby('Country')['InvoiceNo'].count().sort_values()
del grouped_CO['United Kingdom'] # for illustration purpose

# plot number of orders in each country (without UK)
plt.subplots(figsize=(12,8))
grouped_CO.plot(kind='barh', fontsize=10, color='red')
plt.xlabel('Number of Orders', fontsize=14)
plt.ylabel('Country', fontsize=14)
plt.title('Number of Orders for different Countries', fontsize=14)
plt.show()

# %%
#j. Pair plot - All Numeric Variables 

sns.pairplot(data, height=2.5)

# %%
#k. Line chart to show the trend of data - All Numeric/Date Variables 
data.groupby(by=['InvoiceDate'])['total_amount'].sum()[1:]

import matplotlib.pyplot as plt

x = data['total_amount']
y = data['InvoiceDate']
sns.lineplot(data=data, x="InvoiceDate", y="total_amount")
plt.xlabel('Amount spend')
plt.ylabel('date')
plt.title('amount spend each year')
plt.show()

# %%
#l. Plot the skewness - All Numeric Variables

# %%
data.skew(axis = 1, skipna = True) 
plt.plot(data.skew(axis=0,skipna=True))

# %%
#2. Check for missing values in all columns and replace them with the appropriate metric
#(Mean/Median/Mode) 

data.isnull().sum()

# %%
data
data['CustomerID'].isnull().sum()
# Out:
# 135080

# %%
data['CustomerID'].mean()
# Out:
# 15287.690570239585

# %%
import numpy as np
data['CustomerID'].replace(np.NaN , data['CustomerID'].mean()).head(622)
# Out:
# 0      17850.0
# 1      17850.0
# 2      17850.0
# 3      17850.0
# 4      17850.0
#         ...
# 617    17920.0
# 618    17920.0
# 619    17920.0
# 620    17920.0
# 621    17920.0
# Name: CustomerID, Length: 622, dtype: float64

# %%
data[data.isnull().any(axis=1)].head()
# Out:
#      InvoiceNo StockCode                      Description  Quantity  \
# 622     536414     22139                              NaN        56
# 1443    536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444    536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445    536544     21786               POLKADOT RAIN HAT          4
# 1446    536544     21787            RAIN PONCHO RETROSPOT         2
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 622   12/1/2010 11:52       0.00         NaN  United Kingdom
# 1443  12/1/2010 14:32       2.51         NaN  United Kingdom
# 1444  12/1/2010 14:32       2.51         NaN  United Kingdom
# 1445  12/1/2010 14:32       0.85         NaN  United Kingdom
# 1446  12/1/2010 14:32       1.66         NaN  United Kingdom

# %%
#3. Remove duplicate rows 

data.duplicated(subset=None, keep='first')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 541909, dtype: bool

# %%
data.drop_duplicates(subset=None, keep='first', inplace=False)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#4. Remove rows which have negative values in Quantity column 

data = data[data.Quantity > 0]

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
#5. Add the columns - Month, Day and Hour for the invoice 

data.insert(loc=2, column='year', value=pd.DatetimeIndex(data['InvoiceDate']).map(lambda x:x.year))

data.insert(loc=3, column='month', value=data.InvoiceDate.dt.month)
 
data.insert(loc=4, column='day', value=(data.InvoiceDate.dt.dayofweek)+1)
data.insert(loc=5, column='hour', value=data.InvoiceDate.dt.hour)
data.head()
# Out:
#   InvoiceNo StockCode  year_month  month  day  hour  \
# 0    536365    85123A      201012     12    3     8
# 1    536365     71053      201012     12    3     8
# 2    536365    84406B      201012     12    3     8
# 3    536365    84029G      201012     12    3     8
# 4    536365    84029E      201012     12    3     8
#
#                            Description  Quantity         InvoiceDate  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6 2010-12-01 08:26:00
# 1                  WHITE METAL LANTERN         6 2010-12-01 08:26:00
# 2       CREAM CUPID HEARTS COAT HANGER         8 2010-12-01 08:26:00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6 2010-12-01 08:26:00
# 4       RED WOOLLY HOTTIE WHITE HEART.         6 2010-12-01 08:26:00
#
#    UnitPrice  CustomerID         Country  total_amount
# 0       2.55     17850.0  United Kingdom         15.30
# 1       3.39     17850.0  United Kingdom         20.34
# 2       2.75     17850.0  United Kingdom         22.00
# ...

# %%
#6. How many orders made by the customers? 
Orders = data.groupby(by=['CustomerID','Country'], as_index=False)['InvoiceNo'].count()

plt.subplots(figsize=(11,6))
plt.plot(Orders.CustomerID, Orders.InvoiceNo)
plt.xlabel('Customers ID')
plt.ylabel('Number of Orders')
plt.title('Number of Orders for different Customers')
plt.show()

# %%
#7. TOP 5 customers with higher number of orders 


print( 'Top 5 customers with highest number of orders :')

Orders.sort_values(by='InvoiceNo', ascending=False).head()
# Out:
# Top 5 customers with highest number of orders :
#       CustomerID         Country  InvoiceNo
# 4050     17841.0  United Kingdom       7983
# 1903     14911.0            EIRE       5903
# 1308     14096.0  United Kingdom       5128
# 338      12748.0  United Kingdom       4642
# 1682     14606.0  United Kingdom       2782

# %%
#8. How much money spent by the customers? 

money_spent = data_1.groupby(by=['CustomerID','Country'], as_index=False)['total_amount'].sum()

plt.subplots(figsize=(15,6))
plt.plot(money_spent.CustomerID, money_spent.total_amount)
plt.xlabel('Customers ID')
plt.ylabel('Money spent (Dollar)')
plt.title('Money Spent for different Customers')
plt.show()

# %%
#9. TOP 5 customers with highest money spent 

money_spent.sort_values(by='total_amount', ascending=False).head()
# Out:
#       CustomerID         Country  total_amount
# 1698     14646.0     Netherlands     280206.02
# 4210     18102.0  United Kingdom     259657.30
# 3737     17450.0  United Kingdom     194550.79
# 3017     16446.0  United Kingdom     168472.50
# 1888     14911.0            EIRE     143825.06

# %%
#10. How many orders per month? 

data_1 = data.groupby('InvoiceNo')['year_month'].unique().value_counts().sort_index().plot(kind = 'bar',color='red',figsize=(15,6))
data_1.set_xlabel('Month',fontsize=14)
data_1.set_ylabel('Number of Orders',fontsize=14)
data_1.set_title('Number of orders for Months (1st Dec 2019 - 30th Dec 2020)',fontsize=14)
data_1.set_xticklabels(('Dec19','Jan20','Feb20','Mar20','Apr20','May20','Jun20','July20','Aug20','Sep20','Oct20','Nov20','Dec20'), rotation='horizontal', fontsize=12)
plt.show()

# %%
#11. How many orders per day? 

data.groupby('InvoiceNo')['day'].unique().value_counts().sort_index()
# Out:
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: day, dtype: int64

# %%
data_1 = data.groupby('InvoiceNo')['day'].unique().value_counts().sort_index().plot(kind = 'bar',color='blue',figsize=(12,4))
data_1.set_xlabel('Day',fontsize=15)
data_1.set_ylabel('Number of Orders',fontsize=15)
data_1.set_title('Number of orders per Day',fontsize=15)
data_1.set_xticklabels(('Monday','Tuesday','Wednesday','Thursday','Friday','Sunday'), rotation='horizontal', fontsize=12)
plt.show()

# %%
#12. How many orders per hour?

data.groupby('InvoiceNo')['hour'].unique().value_counts().iloc[:-1].sort_index()
# Out:
# [6]        1
# [7]       29
# [8]      555
# [9]     1394
# [10]    2226
# [11]    2276
# [12]    3129
# [13]    2637
# [14]    2275
# [15]    2038
# [16]    1100
# [17]     544
# [18]     169
# [19]     144
# [20]      18
# Name: hour, dtype: int64

# %%
data_1 = data.groupby('InvoiceNo')['hour'].unique().value_counts().iloc[:-1].sort_index().plot(kind = 'bar',color='blue',figsize=(15,6))
data_1.set_xlabel('Hour',fontsize=15)
data_1.set_ylabel('Number of Orders',fontsize=15)
data_1.set_title('Number of orders Hours',fontsize=15)
data_1.set_xticklabels(range(6,21), rotation='horizontal', fontsize=15)
plt.show()

# %%
#13. How many orders for each country? 


group_CO = data.groupby('Country')['InvoiceNo'].count().sort_values()
del group_CO['United Kingdom']


plt.subplots(figsize=(15,8))
group_CO.plot(kind = 'barh', fontsize=12, color='blue')
plt.xlabel('Number of Orders', fontsize=10)
plt.ylabel('Country', fontsize=10)
plt.title('Number of Orders for different Countries', fontsize=10)
plt.show()

# %%
#14. Orders trend across months

data.groupby('InvoiceNo')['month'].unique().value_counts().iloc[:-1].sort_index()


data_1 = data.groupby('InvoiceNo')['month'].unique().value_counts().iloc[:-1].sort_index().plot(kind = 'bar',color='blue',figsize=(15,6))
data_1.set_xlabel('month',fontsize=15)
data_1.set_ylabel('Number of Orders',fontsize=15)
data_1.set_title('Number of orders per month',fontsize=15)
data_1.set_xticklabels(range(6,21), rotation='horizontal', fontsize=15)
plt.show()

# %%
#15. How much money spent by each country? 

group_CO = data.groupby('Country')['total_amount'].count().sort_values()
del group_CO['United Kingdom']


plt.subplots(figsize=(15,8))
group_CO.plot(kind = 'barh', fontsize=12, color='blue')
plt.xlabel('money spent ', fontsize=10)
plt.ylabel('Country', fontsize=10)
plt.title(' Money spent by each country', fontsize=10)
plt.show()
